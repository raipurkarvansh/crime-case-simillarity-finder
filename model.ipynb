# %%
import pandas as pd

# %%
# load dataset
df = pd.read_csv("dataset_fir.csv")

# %%
df
# Out:
#      case_id                                            summary   location  \
# 0          1   Mary was robbed at gunpoint near Tapia Parkways.       Pune
# 1          2   Keith had their phone snatched on Cooper Spring.  Bangalore
# 2          3   Dean was attacked with a knife at Swanson Plaza.     Jaipur
# 3          4  John saw a group vandalizing vehicles near Ern...       Pune
# 4          5  Alan faced an assault incident around Carney F...       Pune
# ..       ...                                                ...        ...
# 995      996  Amber was attacked with a knife at Hudson Corn...     Nagpur
# 996      997  Carla faced an assault incident around Miller ...    Chennai
# 997      998  Kenneth faced an assault incident around Jessi...  Hyderabad
# 998      999        Ian was robbed at gunpoint near Linda Lane.      Delhi
# 999     1000   Roger was robbed at gunpoint near Brenda Circle.       Pune
#
#     date_reported      lat      lon  status closed_date  time_to_solve  \
# 0      2024-11-18  18.5204  73.8567    Open         NaN            189
# 1      2024-12-29  12.9716  77.5946  Closed  2025-02-14             47
# 2      2024-10-25  26.9124  75.7873  Closed  2024-11-06             12
# 3      2024-06-04  18.5204  73.8567  Closed  2024-08-05             62
# 4      2024-10-30  18.5204  73.8567    Open         NaN            208
# ..            ...      ...      ...     ...         ...            ...
# 995    2024-08-25  21.1458  79.0882    Open         NaN            274
# 996    2025-04-29  13.0827  80.2707  Closed  2025-05-23             24
# 997    2025-04-09  17.3850  78.4867    Open         NaN             47
# 998    2024-06-28  28.6139  77.2090  Closed  2024-07-18             20
# 999    2024-09-19  18.5204  73.8567    Open         NaN            249
#
#     case_status
# 0          Open
# 1        Closed
# 2        Closed
# 3        Closed
# 4          Open
# ..          ...
# 995        Open
# 996      Closed
# 997        Open
# 998      Closed
# 999        Open
#
# [1000 rows x 10 columns]

# %%
# checking the null values

df.isnull().sum()
# Out:
# case_id            0
# summary            0
# location           0
# date_reported      0
# lat                0
# lon                0
# status             0
# closed_date      503
# time_to_solve      0
# case_status        0
# dtype: int64

# %%
# TF-IDF vectorization

from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(df['summary'])

# %%
# save the model

import pickle

with open("tfidf_vectorizer.pkl", "wb") as f:
    pickle.dump(vectorizer, f)

with open("tfidf_matrix.pkl", "wb") as f:
    pickle.dump(tfidf_matrix, f)
